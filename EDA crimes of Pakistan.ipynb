# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./Crimes_Pakistan.csv")

# %%
#Total Crimes Record Year wise
totalcrimes=df[df['Offence']=='TOTAL RECORDED CRIME']
ax=totalcrimes[['Year','Pakistan']].plot.bar(x='Year')

# %%
#most railways crimes year wise
Railways=df[['Year','Offence','Railways']]
Railways=Railways[Railways['Offence']=="TOTAL RECORDED CRIME"]

# %%
Railways[['Year','Railways']].plot.bar(x="Year")

# %%
#Most Murders in Pakistan Year wise
Murders=df[df['Offence']=='Murder']
Murders[['Year','Pakistan']].plot.bar(x='Year')

# %%
#murder analysis
crimes_year=df
Murders_per_region=crimes_year[crimes_year['Offence']=='Murder']
Murders_per_region[['Year','Punjab', 'Sindh', 'KP', 'Balochistan',
       'Islamabad', 'Railways', 'G.B', 'AJK']].plot.bar(x='Year')
#below plot approves that most of the murders happens in punjab each year

# %%
#which province least crimes are happened
Crimes_per_region=crimes_year[crimes_year['Offence']=='TOTAL RECORDED CRIME']
Crimes_per_region[['Year','Offence','Punjab', 'Sindh', 'KP', 'Balochistan',
       'Islamabad', 'Railways', 'G.B', 'AJK']].plot.bar(x='Year')
#Punjab have highest crime rate per year

# %%
Crimes_per_region=crimes_year[crimes_year['Offence']=='TOTAL RECORDED CRIME']
Crimes_per_region[['Offence','Punjab', 'Sindh', 'KP', 'Balochistan',
       'Islamabad', 'Railways', 'G.B', 'AJK']].plot.bar(x='Offence')
#Punjab have total highest crime recorded
#Islamabad (federal have lowest crime recorded)
